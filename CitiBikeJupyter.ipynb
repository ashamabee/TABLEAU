# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
Jan2020csv_file = "Resources/202001-citibike-tripdata.csv"
Jan2020 = pd.read_csv(Jan2020csv_file)

# %%
Feb2020csv_file = "Resources/202002-citibike-tripdata.csv"
Feb2020 = pd.read_csv(Feb2020csv_file)

# %%
Mar2020csv_file = "Resources/202003-citibike-tripdata.csv"
Mar2020 = pd.read_csv(Mar2020csv_file)

# %%
Apr2020csv_file = "Resources/202004-citibike-tripdata.csv"
Apr2020 = pd.read_csv(Apr2020csv_file)

# %%
May2020csv_file = "Resources/202005-citibike-tripdata.csv"
May2020 = pd.read_csv(May2020csv_file)

# %%
Jun2020csv_file = "Resources/202006-citibike-tripdata.csv"
Jun2020 = pd.read_csv(Jun2020csv_file)

# %%
Jul2020csv_file = "Resources/202007-citibike-tripdata.csv"
Jul2020 = pd.read_csv(Jul2020csv_file)

# %%
Aug2020csv_file = "Resources/202008-citibike-tripdata.csv"
Aug2020 = pd.read_csv(Aug2020csv_file)

# %%
Sep2020csv_file = "Resources/202009-citibike-tripdata.csv"
Sep2020 = pd.read_csv(Sep2020csv_file)

# %%
Oct2020csv_file = "Resources/202010-citibike-tripdata.csv"
Oct2020 = pd.read_csv(Oct2020csv_file)

# %%
import pandas as pd
import glob
import os
import os.path

# %%
path = r'C:\Users\ashle\OneDrive\Desktop\Data Analytics Class\Homework\TABLEAU\Resources' # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))
CityBike2020 = pd.concat((pd.read_csv(f) for f in all_files))

# %%
CityBike2020 = CityBike2020.rename(columns={"tripduration":"Trip Duration","starttime":"Start Time","stoptime":"Stop Time","start station id":"Start Station ID","start station name":"Start Station Name","start station latitude":"Start Station Latitude","start station longitude":"Start Station Longitude","end station id":"End Station ID","end station name":"End Station Name","end station latitude":"End Station Latitude", "end station longitude": "End Station Longitude","bikeid":"Bike ID","usertype":"User Type","birth year":"Birth Year","gender":"Gender"})

# %%
CityBike2020.dtypes
# Out:
# Trip Duration                int64
# Start Time                  object
# Stop Time                   object
# Start Station ID             int64
# Start Station Name          object
# Start Station Latitude     float64
# Start Station Longitude    float64
# End Station ID               int64
# End Station Name            object
# End Station Latitude       float64
# End Station Longitude      float64
# Bike ID                      int64
# User Type                   object
# Birth Year                   int64
# Gender                       int64
# dtype: object

# %%
CityBike2020
# Out:
#          Trip Duration                Start Time                 Stop Time  \
# 0                  789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                 1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                 1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                  592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                  702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...                ...                       ...                       ...
# 2248864           1120  2020-10-31 23:59:48.4470  2020-11-01 00:18:29.3280
# 2248865            859  2020-10-31 23:59:49.3770  2020-11-01 00:14:09.1920
# 2248866            546  2020-10-31 23:59:52.1040  2020-11-01 00:08:59.0710
# 2248867            748  2020-10-31 23:59:53.0290  2020-11-01 00:12:21.7830
# 2248868           1366  2020-10-31 23:59:57.9770  2020-11-01 00:22:44.1290
#
#          Start Station ID                  Start Station Name  \
# ...

# %%
CityBike2020.to_csv("CityBike2020Data.csv", index=False)
